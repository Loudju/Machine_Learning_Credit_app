# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts

# %%
# Read csv file
df = pd.read_csv('df_train.csv')
df.head()
# Out:
#    Current Loan Amount        Term  Credit Scores  Years in current job  \
# 0                  491  Short Term            715                     1
# 1                  701  Short Term            718                     1
# 2                  885  Short Term            731                     3
# 3                  975  Short Term            713                     6
# 4                  975  Short Term            694                    10
#
#   Home Ownership  Annual Income             Purpose  Monthly Debt  \
# 0  Home Mortgage          72254         Take a Trip         19.67
# 1           Rent          19040  Debt Consolidation        196.74
# 2           Rent          11801  Educatiol Expenses        164.23
# 3           Rent          24378       Medical Bills        692.73
# 4  Home Mortgage          59599         Take a Trip       1157.22
#
#    Annual Debt  Debt to Income Ratio  ... Years of Credit History  \
# ...

# %%
list(df.columns)
# Out:
# ['Current Loan Amount',
#  'Term',
#  'Credit Scores',
#  'Years in current job',
#  'Home Ownership',
#  'Annual Income',
#  'Purpose',
#  'Monthly Debt',
#  'Annual Debt',
#  'Debt to Income Ratio',
#  'Debt to Income Ratio G/B',
#  'Years of Credit History',
#  'Number of Open Accounts',
#  'Number of Credit Problems',
#  'Utilization Rate Good/Bad',
#  'Utilization Rate',
#  'Current Credit Balance',
#  'Maximum Open Credit',
#  'Bankruptcies',
#  'Tax Liens',
#  'Loan Status']

# %%
# Determine if the column is normally distributed
plt.hist(df['Current Loan Amount'])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('none')
ax1.boxplot(df['Current Loan Amount'])

print(sts.normaltest(df['Current Loan Amount']))
# Out:
# NormaltestResult(statistic=4149.536305470615, pvalue=0.0)

# %%
# Determine if the column is normally distributed
plt.hist(df['Credit Scores'])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('none')
ax1.boxplot(df['Credit Scores'])

print(sts.normaltest(df['Credit Scores']))
# Out:
# NormaltestResult(statistic=14815.885477843902, pvalue=0.0)

# %%
# Determine if the column is normally distributed
plt.hist(df['Years in current job'])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('none')
ax1.boxplot(df['Years in current job'])

print(sts.normaltest(df['Years in current job']))
# Out:
# NormaltestResult(statistic=305484.88694476406, pvalue=0.0)

# %%
# Determine if the column is normally distributed
plt.hist(df['Annual Income'])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('none')
ax1.boxplot(df['Annual Income'])

print(sts.normaltest(df['Annual Income']))
# Out:
# NormaltestResult(statistic=188297.73496334165, pvalue=0.0)

# %%
# Determine if the column is normally distributed
plt.hist(df['Monthly Debt'])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('none')
ax1.boxplot(df['Monthly Debt'])

print(sts.normaltest(df['Monthly Debt']))
# Out:
# NormaltestResult(statistic=20598.623691429762, pvalue=0.0)

# %%
# Determine if the column is normally distributed
plt.hist(df['Annual Debt'])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('none')
ax1.boxplot(df['Annual Debt'])

print(sts.normaltest(df['Annual Debt']))
# Out:
# NormaltestResult(statistic=20598.623691429773, pvalue=0.0)

# %%
# Determine if the column is normally distributed
plt.hist(df['Debt to Income Ratio'])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('none')
ax1.boxplot(df['Debt to Income Ratio'])

print(sts.normaltest(df['Debt to Income Ratio']))
# Out:
# NormaltestResult(statistic=561.1343479409654, pvalue=1.4165259710607596e-122)

# %%
# Determine if the column is normally distributed
plt.hist(df['Years of Credit History'])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('none')
ax1.boxplot(df['Years of Credit History'])

print(sts.normaltest(df['Years of Credit History']))
# Out:
# NormaltestResult(statistic=8771.789369905728, pvalue=0.0)

# %%
# Determine if the column is normally distributed
plt.hist(df['Number of Open Accounts'])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('none')
ax1.boxplot(df['Number of Open Accounts'])

print(sts.normaltest(df['Number of Open Accounts']))
# Out:
# NormaltestResult(statistic=12897.794839894574, pvalue=0.0)

# %%
# Determine if the column is normally distributed
plt.hist(df['Number of Open Accounts'])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('none')
ax1.boxplot(df['Number of Open Accounts'])

print(sts.normaltest(df['Number of Open Accounts']))
# Out:
# NormaltestResult(statistic=12897.794839894574, pvalue=0.0)

# %%
# Determine if the column is normally distributed
plt.hist(df['Number of Credit Problems'])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('none')
ax1.boxplot(df['Number of Credit Problems'])

print(sts.normaltest(df['Number of Credit Problems']))
# Out:
# NormaltestResult(statistic=55908.73627925299, pvalue=0.0)

# %%
# Determine if the column is normally distributed
plt.hist(df['Utilization Rate'])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('none')
ax1.boxplot(df['Utilization Rate'])

print(sts.normaltest(df['Utilization Rate']))
# Out:
# NormaltestResult(statistic=3615.2769087325487, pvalue=0.0)

# %%
# Determine if the column is normally distributed
plt.hist(df['Current Credit Balance'])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('none')
ax1.boxplot(df['Current Credit Balance'])

print(sts.normaltest(df['Current Credit Balance']))
# Out:
# NormaltestResult(statistic=84244.95938968936, pvalue=0.0)

# %%
# Determine if the column is normally distributed
plt.hist(df['Number of Credit Problems'])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('none')
ax1.boxplot(df['Number of Credit Problems'])

print(sts.normaltest(df['Number of Credit Problems']))

# %%
# Determine if the column is normally distributed
plt.hist(df['Maximum Open Credit'])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('none')
ax1.boxplot(df['Maximum Open Credit'])

print(sts.normaltest(df['Maximum Open Credit']))
# Out:
# NormaltestResult(statistic=216270.74150778292, pvalue=0.0)

# %%
# Determine if the column is normally distributed
plt.hist(df['Number of Credit Problems'])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('none')
ax1.boxplot(df['Number of Credit Problems'])

print(sts.normaltest(df['Number of Credit Problems']))

# %%
# Determine if the column is normally distributed
plt.hist(df['Bankruptcies'])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('none')
ax1.boxplot(df['Bankruptcies'])

print(sts.normaltest(df['Bankruptcies']))
# Out:
# NormaltestResult(statistic=38901.31015077399, pvalue=0.0)

# %%
# Determine if the column is normally distributed
plt.hist(df['Tax Liens'])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('none')
ax1.boxplot(df['Tax Liens'])

print(sts.normaltest(df['Tax Liens']))
# Out:
# NormaltestResult(statistic=108717.40568518633, pvalue=0.0)

# %%
# Determine if the column is normally distributed
plt.hist(df['Loan Status'])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('none')
ax1.boxplot(df['Loan Status'])

print(sts.normaltest(df['Loan Status']))
# Out:
# NormaltestResult(statistic=16874.660316441994, pvalue=0.0)
